# %% [markdown]
# Importing the dependencies

# %%
import pandas as pd
import warnings
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from joblib import dump
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3872\4242996366.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# Data Collection and Preprocessing

# %%
business_data =pd.read_csv("business_growth_dataset.csv")

# %%
# business_data = pd.get_dummies(business_data, columns=['Type of Business', 'Business Size', 'Geographic Location', 'Distribution Channels', 'Customer Demographics', 'Partnerships and Alliances'])

# %%
business_data.head()
# Out:
#    Revenue (Shillings)  Profit (Shillings)  Loss (Shillings)  \
# 0         48407.440944        46928.907584      29161.564632
# 1         23812.371301        35546.622129      35008.415047
# 2         14123.495478        28126.385447      29179.374178
# 3          6266.095291        27410.909006      14992.491127
# 4         11975.050248        21028.533862       3149.587061
#
#    Customer Acquisition Cost (Shillings)  Customer Lifetime Value (Shillings)  \
# 0                           44767.112828                          4618.368372
# 1                           20206.607438                          7471.312226
# 2                           47181.584335                         42189.535567
# 3                           41090.912637                         14377.719547
# 4                           14585.467805                         31505.616263
#
#    Market Share (Percentage)  Customer Satisfaction (Percentage)  \
# ...

# %%
business_data.tail()
# Out:
#        Revenue (Shillings)  Profit (Shillings)  Loss (Shillings)  \
# 29995          1545.956924        30831.261538      25089.364806
# 29996         46872.943673         3602.905154      22945.019153
# 29997          4054.772694        16855.111648      38461.259973
# 29998          4827.461402        21931.619826      11944.615222
# 29999         14100.398422        26823.884771      25561.588062
#
#        Customer Acquisition Cost (Shillings)  \
# 29995                              63.477557
# 29996                           29990.754242
# 29997                            1164.156557
# 29998                           41484.712939
# 29999                           20281.740448
#
#        Customer Lifetime Value (Shillings)  Market Share (Percentage)  \
# 29995                         22124.807025                  16.209768
# 29996                          6507.157314                  56.566407
# 29997                         47438.345736                  92.366517
# ...

# %%
business_data.shape
# Out:
# (30000, 39)

# %%
business_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 39 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Revenue (Shillings)                                   30000 non-null  float64
#  1   Profit (Shillings)                                    30000 non-null  float64
#  2   Loss (Shillings)                                      30000 non-null  float64
#  3   Customer Acquisition Cost (Shillings)                 30000 non-null  float64
#  4   Customer Lifetime Value (Shillings)                   30000 non-null  float64
#  5   Market Share (Percentage)                             30000 non-null  float64
#  6   Customer Satisfaction (Percentage)                    30000 non-null  float64
#  7   Employee Satisfaction (Percentage)                    30000 non-null  float64
# ...

# %%
business_data.isnull().sum()
# Out:
# Revenue (Shillings)                                     0
# Profit (Shillings)                                      0
# Loss (Shillings)                                        0
# Customer Acquisition Cost (Shillings)                   0
# Customer Lifetime Value (Shillings)                     0
# Market Share (Percentage)                               0
# Customer Satisfaction (Percentage)                      0
# Employee Satisfaction (Percentage)                      0
# Product Quality (Rating out of 10)                      0
# Innovation (Rating out of 10)                           0
# Market Trends (Rating out of 10)                        0
# Type of Business                                        0
# Business Size                                           0
# Geographic Location                                     0
# Industry Trends (Percentage)                            0
# Business Reputation (Percentage)                        0
# ...

# %%
business_data.describe()
# Out:
#        Revenue (Shillings)  Profit (Shillings)  Loss (Shillings)  \
# count         30000.000000        30000.000000      30000.000000
# mean          25023.445660        25028.145685      25149.071472
# std           14327.576345        14449.823099      14402.881696
# min               0.887188            3.132995          0.838716
# 25%           12760.294578        12510.210126      12806.746097
# 50%           24968.123542        25059.524078      25141.100777
# 75%           37250.107340        37516.915065      37547.307359
# max           49998.797801        49997.913261      49999.899175
#
#        Customer Acquisition Cost (Shillings)  \
# count                           30000.000000
# mean                            24946.423021
# std                             14441.772050
# min                                 1.791318
# 25%                             12433.127631
# 50%                             24854.185895
# 75%                             37475.894153
# ...

# %%
business_data ['Target'].value_counts()
# Out:
# Target
# 1    24027
# 0     5973
# Name: count, dtype: int64

# %% [markdown]
# 1-->Indicates that the business experienced growth after one year.
#
#
# 0--> Indicates that the business did not experience growth after one year

# %% [markdown]
# Splitting the Features and Target

# %%
X= business_data.drop(columns='Target',axis=1)
Y=business_data['Target']

# %%
print(X)
# Out:
#        Revenue (Shillings)  Profit (Shillings)  Loss (Shillings)  \
# 0             48407.440944        46928.907584      29161.564632
# 1             23812.371301        35546.622129      35008.415047
# 2             14123.495478        28126.385447      29179.374178
# 3              6266.095291        27410.909006      14992.491127
# 4             11975.050248        21028.533862       3149.587061
# ...                    ...                 ...               ...
# 29995          1545.956924        30831.261538      25089.364806
# 29996         46872.943673         3602.905154      22945.019153
# 29997          4054.772694        16855.111648      38461.259973
# 29998          4827.461402        21931.619826      11944.615222
# 29999         14100.398422        26823.884771      25561.588062
#
#        Customer Acquisition Cost (Shillings)  \
# 0                               44767.112828
# 1                               20206.607438
# 2                               47181.584335
# ...

# %%
print(Y)
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 29995    1
# 29996    1
# 29997    1
# 29998    1
# 29999    0
# Name: Target, Length: 30000, dtype: int64

# %%
X_train, X_test ,Y_train,Y_test = train_test_split (X,Y,test_size=0.2,stratify=Y, random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (30000, 38) (24000, 38) (6000, 38)

# %% [markdown]
# Model Training Logistic Regression

# %%
model=LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3872\4153405994.py in ?()
# ----> 1 model.fit(X_train,Y_train)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1470                 skip_parameter_validation=(
#    1471                     prefer_skip_nested_validation or global_skip_validation
#    1472                 )
#    1473             ):
# -> 1474                 return fit_method(estimator, *args, **kwargs)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_logistic.py in ?(self, X, y, sample_weight)
#    1197             _dtype = np.float64
#    1198         else:
# ...

# %% [markdown]
# Model Evaluation
#
# Accuracy Score

# %%
X_train_prediction= model.predict(X_train)
training_data_accuracy= accuracy_score(X_train_prediction,Y_train)

# %%
print('Accuracy on Training data',training_data_accuracy)
# Out:
# Accuracy on Training data 0.8009166666666667

# %%
X_test_prediction= model.predict(X_test)
test_data_accuracy=accuracy_score(X_test_prediction,Y_test)

# %%
print('Accuracy of the test data: ',test_data_accuracy)
# Out:
# Accuracy of the test data:  0.8008333333333333

# %%
input_data =(29189.38152728694,16626.181610548523,
             46879.75989986687,5072.821389815557,41680.39046719604,
             23.252249951944915,68.43102168073915,50.013906255783915,
             7.586378619791025,7.878806745883282,7.856405889487141,69.04879822367464,14.53646625191094,
             1.572968373146677,69.40623906217577,24.164342751180534,
             1.4769511399274948,2.2224751870424453,93.53578053733229,27.93408863469867,
             0.17844052241587915,1.5157742311884759,4.661194821241887,
             16.497643512229065,98.89930091215842,94.51143799933459,
             7.777736730858189,4.523935169029397,42.948071416884495,
             42.51002576672297,86.71133643364944,73.17483607881489,
)

#change the input data to a numpy array

input_data_as_numpy_array=np.asarray(input_data)

#resahpe the numpy array as we are predicting for only on instance

input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)
prediction= model.predict(input_data_reshaped)
print(prediction)

if(prediction[0]==0):
    print('The business will not  grow after one year')

else:
    print('The business will grow after one year')
# Out:
# C:\Users\ADMIN\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 20
#      17 #resahpe the numpy array as we are predicting for only on instance
#      19 input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)
# ---> 20 prediction= model.predict(input_data_reshaped)
#      21 print(prediction)
#      23 if(prediction[0]==0):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_base.py:351, in LinearClassifierMixin.predict(self, X)
#     337 """
# ...
