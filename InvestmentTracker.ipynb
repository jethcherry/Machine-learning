# %% [markdown]
# Importing the dependencies

# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from joblib import dump

# %% [markdown]
# Data Collection and Preprocessing

# %%
business_data =pd.read_csv("business_growth_dataset.csv")

# %%
business_data.head()
# Out:
#    Revenue (Shillings)  Profit (Shillings)  Loss (Shillings)  \
# 0          30493.39609        28231.485680      16605.728240
# 1          43482.38981        14228.374410       6486.395093
# 2          22117.06073         1676.959718      47066.071820
# 3          21100.57239        48479.621910       9285.995700
# 4          33799.93214        41390.250880      34942.233870
#
#    Customer Acquisition Cost (Shillings)  Customer Lifetime Value (Shillings)  \
# 0                            7096.728367                         19818.497300
# 1                           10604.787200                         40499.540350
# 2                            1190.190378                          8082.573205
# 3                           30316.192840                          9586.008292
# 4                           48999.474180                         39192.721310
#
#    Market Share (Percentage)  Customer Satisfaction (Percentage)  \
# ...

# %%
business_data.tail()
# Out:
#        Revenue (Shillings)  Profit (Shillings)  Loss (Shillings)  \
# 29995         40773.142590        40089.108090      24605.716940
# 29996          6976.820036         2778.990857       5393.265623
# 29997         47667.334110        42805.163000      47982.892100
# 29998         30394.825820        48299.599640      27378.187580
# 29999         49816.184660        36863.411360      10293.930440
#
#        Customer Acquisition Cost (Shillings)  \
# 29995                            21365.64657
# 29996                             4678.27480
# 29997                            24883.06541
# 29998                            49887.40854
# 29999                            27262.80637
#
#        Customer Lifetime Value (Shillings)  Market Share (Percentage)  \
# 29995                          4071.608187                   2.353353
# 29996                         22390.428480                  54.322815
# 29997                         26587.114610                   9.820316
# ...

# %%
business_data.sample(20)
# Out:
#        Revenue (Shillings)  Profit (Shillings)  Loss (Shillings)  \
# 10970         35895.079550         5644.748978      43331.428520
# 11044         37031.531040         8835.557375       4316.834786
# 21384         12052.975280         1131.086503       7195.892987
# 11126         41451.321100         7984.311939      26108.451430
# 15700         13010.683260        13620.706430      25786.827170
# 9669          15020.045110        44304.593690       3641.612310
# 876            1249.680417        38406.454270      33135.300310
# 405            1150.478484         9429.010720        807.071113
# 19952         37970.572360        28100.509330      28866.623450
# 13301         37055.135130        38888.325030      35100.331550
# 9456            743.304773        31942.733860       4832.937075
# 14863         45996.100330        29386.432600      38479.283290
# 7387          27308.481990        40527.157310      21026.205050
# ...

# %%
business_data.shape
# Out:
# (30000, 39)

# %%
business_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 39 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Revenue (Shillings)                                   30000 non-null  float64
#  1   Profit (Shillings)                                    30000 non-null  float64
#  2   Loss (Shillings)                                      30000 non-null  float64
#  3   Customer Acquisition Cost (Shillings)                 30000 non-null  float64
#  4   Customer Lifetime Value (Shillings)                   30000 non-null  float64
#  5   Market Share (Percentage)                             30000 non-null  float64
#  6   Customer Satisfaction (Percentage)                    30000 non-null  float64
#  7   Employee Satisfaction (Percentage)                    30000 non-null  float64
# ...

# %%
business_data.isnull().sum()
# Out:
# Revenue (Shillings)                                     0
# Profit (Shillings)                                      0
# Loss (Shillings)                                        0
# Customer Acquisition Cost (Shillings)                   0
# Customer Lifetime Value (Shillings)                     0
# Market Share (Percentage)                               0
# Customer Satisfaction (Percentage)                      0
# Employee Satisfaction (Percentage)                      0
# Product Quality (Rating out of 10)                      0
# Innovation (Rating out of 10)                           0
# Market Trends (Rating out of 10)                        0
# Type of Business                                        0
# Business Size                                           0
# Geographic Location                                     0
# Industry Trends (Percentage)                            0
# Business Reputation (Percentage)                        0
# ...

# %%
business_data.describe()
# Out:
#        Revenue (Shillings)  Profit (Shillings)  Loss (Shillings)  \
# count         30000.000000        30000.000000      30000.000000
# mean          24983.147861        25075.152114      24926.397132
# std           14422.114392        14454.727237      14506.766958
# min               0.637881            0.379401          2.680385
# 25%           12425.736222        12560.478358      12305.706860
# 50%           25043.594425        25121.182045      24920.778675
# 75%           37383.504875        37590.003620      37543.468948
# max           49998.845810        49997.789280      49999.197510
#
#        Customer Acquisition Cost (Shillings)  \
# count                           30000.000000
# mean                            25015.860364
# std                             14411.981716
# min                                 5.029969
# 25%                             12612.350202
# 50%                             24959.845585
# 75%                             37478.231047
# ...

# %%
business_data ['Target'].value_counts()
# Out:
# Target
# 1    24000
# 0     6000
# Name: count, dtype: int64

# %% [markdown]
# 1-->Indicates that the business experienced growth after one year.
#
#
# 0--> Indicates that the business did not experience growth after one year

# %% [markdown]
# Splitting the Features and Target

# %%
X= business_data.drop(columns='Target',axis=1)
Y=business_data['Target']

# %%
print(X)
# Out:
#        Revenue (Shillings)  Profit (Shillings)  Loss (Shillings)  \
# 0             30493.396090        28231.485680      16605.728240
# 1             43482.389810        14228.374410       6486.395093
# 2             22117.060730         1676.959718      47066.071820
# 3             21100.572390        48479.621910       9285.995700
# 4             33799.932140        41390.250880      34942.233870
# ...                    ...                 ...               ...
# 29995         40773.142590        40089.108090      24605.716940
# 29996          6976.820036         2778.990857       5393.265623
# 29997         47667.334110        42805.163000      47982.892100
# 29998         30394.825820        48299.599640      27378.187580
# 29999         49816.184660        36863.411360      10293.930440
#
#        Customer Acquisition Cost (Shillings)  \
# 0                                7096.728367
# 1                               10604.787200
# 2                                1190.190378
# ...

# %%
print(Y)
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 29995    1
# 29996    0
# 29997    1
# 29998    1
# 29999    1
# Name: Target, Length: 30000, dtype: int64

# %%
X_train, X_test ,Y_train,Y_test = train_test_split (X,Y,test_size=0.2,stratify=Y, random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (30000, 38) (24000, 38) (6000, 38)

# %% [markdown]
# Model Training Logistic Regression

# %%
model=LogisticRegression()

# %%
df_encoded = pd.get_dummies(business_data)

# %%
model.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8692\4153405994.py in ?()
# ----> 1 model.fit(X_train,Y_train)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1470                 skip_parameter_validation=(
#    1471                     prefer_skip_nested_validation or global_skip_validation
#    1472                 )
#    1473             ):
# -> 1474                 return fit_method(estimator, *args, **kwargs)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_logistic.py in ?(self, X, y, sample_weight)
#    1197             _dtype = np.float64
#    1198         else:
# ...

# %% [markdown]
# Model Evaluation
#
# Accuracy Score

# %%
X_train_prediction= model.predict(X_train)
training_data_accuracy= accuracy_score(X_train_prediction,Y_train)

# %%
print('Accuracy on Training data',training_data_accuracy)
# Out:
# Accuracy on Training data 0.511375

# %%
X_test_prediction= model.predict(X_test)
test_data_accuracy=accuracy_score(X_test_prediction,Y_test)

# %%
print('Accuracy of the test data: ',test_data_accuracy)
# Out:
# Accuracy of the test data:  0.48966666666666664

# %%
input_data = (2989.9964551194926,24321.126299523356,38704.15339602958,7325.110424825243,7887.182920068559,37.38620885214392,45.35440336671992,76.97093651538441,3.6324666729670985,1.0193413735112367,3.7635966861840178,15,0,0,19.347946768713708,86.82233499556136,0.5793451929701932,30.941770186751217,95.19121297203793,0.316638890851193,1.0680791585807836,25.115174994769884,52.038826376266776,1,1,4.4025736484340925,9.525148649298188,46.37532398142735,51.695707717333136,94.26569912700373,11.68873293601843,0,2.970505666619798,8.219873903365745,79.75735918334372,52.784289975319055,15.152326506017976,11.54964094915102)




input_data_as_numpy_array=np.asarray(input_data)

#resahpe the numpy array as we are predicting for only on instance

input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)
prediction= model.predict(input_data_reshaped)
print(prediction)

if(prediction[0]==0):
    print('The business will not  grow after one year')

else:
    print('The business will grow after one year')
# Out:
# [1]
# The business will grow after one year
# C:\Users\ADMIN\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
