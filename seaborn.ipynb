# %% [markdown]
# SEABORN TUTORIAL

# %%
#import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings
from matplotlib import style
from seaborn import color_palette
warnings.filterwarnings('ignore')

# %%
#used for style your figures for proper visibility
style.use("ggplot")

# %%
#reading data in pandas
data = pd.read_csv("business_growth_dataset.csv")

# %%
#print the first 5 rows 
data.head()
# Out:
#    Revenue (Shillings)  Profit (Shillings)  Loss (Shillings)  \
# 0         29270.351828        26955.918645      39997.221441
# 1           302.404473        19887.511205      46747.540110
# 2          7766.683180          903.056453      18293.441655
# 3         19963.015626        42280.975810      40781.182188
# 4         27920.819146        28859.029263      33768.059065
#
#    Customer Acquisition Cost (Shillings)  Customer Lifetime Value (Shillings)  \
# 0                           35542.933487                         40920.285868
# 1                           17121.413157                         26385.384511
# 2                           31502.577370                          3813.740469
# 3                           34430.670403                         42464.682280
# 4                           19922.852865                         44837.823729
#
#    Market Share (Percentage)  Customer Satisfaction (Percentage)  \
# 0                  49.476948                           37.287396
# 1                  35.455150                           29.009149
# 2                  12.748761                           67.140224
# 3                  21.940761                           54.351098
# 4                  11.943093                           43.210526
#
#    Employee Satisfaction (Percentage)  Product Quality (Rating out of 10)  \
# 0                           87.289599                            1.066545
# 1                           26.764383                            3.788781
# 2                           37.870990                            7.002591
# 3                           47.691500                            5.198271
# 4                           34.203327                            3.517158
#
#    Innovation (Rating out of 10)  ...  \
# 0                       1.964608  ...
# 1                       5.012716  ...
# 2                       5.123280  ...
# 3                       5.440694  ...
# 4                       9.585677  ...
#
#    Intellectual Property Protection (Percentage)  \
# 0                                      59.496981
# 1                                      80.416280
# 2                                      40.296464
# 3                                      67.417508
# 4                                      21.069404
#
#   Market Positioning (Percentage) Seasonal Variations (Percentage)  \
# 0                       25.028234                        43.195926
# 1                       43.656784                        80.974993
# 2                       19.479605                        99.870475
# 3                       19.757829                        45.712910
# 4                       88.014235                        22.777093
#
#   Economic Indicators (Percentage)  Partnerships and Alliances  \
# 0                        76.042797                           1
# 1                        40.101635                           1
# 2                        87.616567                           1
# 3                        92.957689                           1
# 4                         7.565926                           0
#
#    Quality of Leadership (Rating out of 10)  \
# 0                                  5.292689
# 1                                  8.991073
# 2                                  6.615153
# 3                                  6.738595
# 4                                  3.038151
#
#    Employee Morale (Rating out of 10)  Financial Stability (Percentage)  \
# 0                            7.749947                         53.606588
# 1                            9.910352                         43.824384
# 2                            5.982836                         82.002903
# 3                            8.512395                         82.397711
# 4                            7.860328                          3.121490
#
#    Customer Loyalty Programs (Percentage)  \
# 0                               19.510705
# 1                               49.409518
# 2                               39.366420
# 3                               40.352316
# 4                               22.841218
#
#    Online Presence and E-commerce Strategy (Percentage)
# 0                                          80.102371
# 1                                          36.288315
# 2                                          64.582774
# 3                                          19.791802
# 4                                          29.183693
#
# [5 rows x 37 columns]

# %%
#get the dataset names
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
#import data using the lust yiu had generated
crash_df = sns.load_dataset('car_crashes')
crash_df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 19       96.57     ME
# 20      192.70     MD
# 21      135.63     MA
# 22      152.26     MI
# 23      133.35     MN
# 24      155.77     MS
# 25      144.45     MO
# 26       85.15     MT
# 27      114.82     NE
# 28      138.71     NV
# 29      120.21     NH
# 30      159.85     NJ
# 31      120.75     NM
# 32      150.01     NY
# 33      127.82     NC
# 34      109.72     ND
# 35      133.52     OH
# 36      178.86     OK
# 37      104.61     OR
# 38      153.86     PA
# 39      148.58     RI
# 40      116.29     SC
# 41       96.87     SD
# 42      155.57     TN
# 43      156.83     TX
# 44      109.48     UT
# 45      109.61     VT
# 46      153.72     VA
# 47      111.62     WA
# 48      152.56     WV
# 49      106.62     WI
# 50      122.04     WY

# %% [markdown]
# DISTRIBUTION PLOTS

# %%
#write seaborn code to draw a distribution plot
sns.displot(crash_df["not_distracted"],kde = False,bins =25)

# %% [markdown]
# JOINT PLOT

# %%
#plot a joint plot
sns.jointplot(x = "speeding", y = "alcohol",data= crash_df,kind="reg")

# %%
#plot a joint plot
sns.jointplot(x = "speeding", y = "alcohol",data= crash_df,kind="kde")

# %%
#plot a joint plot
sns.jointplot(x = "speeding", y = "alcohol",data= crash_df,kind="hex")

# %% [markdown]
# KDE PLOT

# %%
sns.kdeplot(crash_df["alcohol"],label = "alcohol")
plt.legend()

# %% [markdown]
# PAIR PLOTS

# %%
sns.pairplot(crash_df)

# %%
tips_df = sns.load_dataset("tips")
sns.pairplot(tips_df,hue="sex",palette="Blues")

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
print(tips_df["day"])
# Out:
# 0       Sun
# 1       Sun
# 2       Sun
# 3       Sun
# 4       Sun
#        ...
# 239     Sat
# 240     Sat
# 241     Sat
# 242     Sat
# 243    Thur
# Name: day, Length: 244, dtype: category
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %% [markdown]
# RUG PLOT

# %%
#plot a rugplot the rug plot to visualize the dataset
sns.rugplot(tips_df["tip"])
# Out:
# <Axes: xlabel='tip'>

# %% [markdown]
# STYLING

# %%
sns.set_style("ticks")
plt.figure(figsize=(8,4))
sns.set_context("paper",font_scale=1.4)
sns.despine(left="False")
sns.jointplot(x = "speeding",y="alcohol",data= crash_df,kind = "reg")

# %% [markdown]
# CATEGORICAL PLOTS

# %% [markdown]
# BAR PLOTS

# %%
sns.barplot(x="sex",y="total_bill",data = tips_df,estimator=np.var)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# COUNT PLOTS

# %%
#use count to count the number of occurences
sns.countplot(x = "sex",data = tips_df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# BOX PLOT

# %%
#plotting a boxplot
sns.boxplot(x="day",y="total_bill",data = tips_df,hue="sex")
plt.legend(loc = 0)

# %% [markdown]
# VIOLIN PLOT

# %%
sns.violinplot(x="day",y="total_bill",data = tips_df,hue="sex",split="True")
plt.legend(loc=0)

# %%
sns.violinplot(x = "day",y="total_bill",data = tips_df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# STRIP PLOTS

# %%
plt.figure(figsize=(8,5))
sns.stripplot(x = "day",y="total_bill",data = tips_df,jitter= True,hue="sex",dodge=True)
plt.legend(loc=0)

# %% [markdown]
# SWARM PLOT

# %%
sns.swarmplot(x = "day",y="total_bill",data = tips_df,color="white")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
